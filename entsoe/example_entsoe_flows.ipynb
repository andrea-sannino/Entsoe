# %%
import pandas as pd
from entsoe import EntsoePandasClient
from datetime import timedelta
import numpy as np

# %%
# %% parameter definitions
client = EntsoePandasClient(api_key='db4f6283-0bff-4336-a239-c679bbe96a25')

start = pd.Timestamp('20230101', tz ='Europe/Paris')
end = pd.Timestamp('20240304', tz ='Europe/Paris')
country_code_1 = 'FR'

# %%
 def query_crossborder_flows(
            self, country_code_from: Union[Area, str],
            country_code_to: Union[Area, str], start: pd.Timestamp,
            end: pd.Timestamp, **kwargs)

# %%
historical_flow_DK_DE = client.query_crossborder_flows('DK','DE', start = start, end = end)

# %%
historical_flow_DE_DK.plot()
# Out:
# <Axes: >
